# %% [markdown]
# # 6.2 Exploring relationships

# %% [markdown]
# ### This script contains the following:
#
# #### 1. Importing Visualization Libraries and Cleaned Data
# #### 2. Exploring Relationships
#      Correlations
#      Scatterplots
#      Pair Plots
#      Categorical Plots
# #### 3. Exporting charts and data

# %% [markdown]
# ## 1. Importing Visualization Libraries and Cleaned Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# checking matlab version
matplotlib.__version__
# Out:
# '3.5.1'

# %% [markdown]
# Good to go!!!

# %%
# Identifying pathway for import for ease with multiple imports
path = r'C:\Users\Chris Arnold\Documents\Citibike Analysis'

# %%
# Import data
# Importing citibike_cleaned.csv
Citi_df = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'citibike_cleaned.csv'))

# %%
# Checking the head of the DF 
Citi_df.head()
# Out:
#    Unnamed: 0 trip_id  bike_id weekday  weekday_index  start_hour  \
# 0           0  LnQzQk    16013     Mon              1          18
# 1           1  IL9boN    15230     Thu              4          18
# 2           2  46clGB    17942     Wed              3          19
# 3           3  v7vdFt    19683     Sat              6          11
# 4           4  VGBsb5    18024     Sat              6          18
#
#         start_time  start_station_id       start_station_name  \
# 0   9/9/2013 18:18               523          W 38 St & 8 Ave
# 1  9/12/2013 18:38               257  Lispenard St & Broadway
# 2  9/18/2013 19:44               479          9 Ave & W 45 St
# 3  9/28/2013 11:54               527          E 33 St & 1 Ave
# 4   9/7/2013 18:08               521          8 Ave & W 31 St
#
#    start_station_latitude  ...         end_time end_station_id  \
# 0               40.754666  ...   9/9/2013 18:35            334
# 1               40.719392  ...  9/12/2013 18:48            236
# ...

# %% [markdown]
# ## 2. Exploring Relationships

# %%
# Create a correlation matrix using pandas

Citi_df.corr()
# Out:
#                          Unnamed: 0   bike_id  weekday_index  start_hour  \
# Unnamed: 0                 1.000000  0.005962       0.004003   -0.004379
# bike_id                    0.005962  1.000000      -0.007069   -0.000866
# weekday_index              0.004003 -0.007069       1.000000    0.005601
# start_hour                -0.004379 -0.000866       0.005601    1.000000
# start_station_id          -0.004106  0.003608       0.011768   -0.001270
# start_station_latitude    -0.001500 -0.009604      -0.053146   -0.009121
# start_station_longitude   -0.003327 -0.002193      -0.010987   -0.045734
# end_station_id            -0.005347  0.002357       0.004764    0.004045
# end_station_latitude      -0.000085 -0.006955      -0.047697   -0.036941
# end_station_longitude      0.000781 -0.001598      -0.013953    0.007160
# trip_duration              0.000849  0.003365       0.077492    0.040870
# birth_year                -0.006126  0.004599      -0.136154   -0.030082
# ...

# %%
# Create a correlation heatmap using matplotlib

plt.matshow(Citi_df.corr())
plt.show()

# %% [markdown]
# ### Create a correlation heatmap using seaborn:

# %%
Citi_df.columns
# Out:
# Index(['Unnamed: 0', 'trip_id', 'bike_id', 'weekday', 'weekday_index',
#        'start_hour', 'start_time', 'start_station_id', 'start_station_name',
#        'start_station_latitude', 'start_station_longitude', 'end_time',
#        'end_station_id', 'end_station_name', 'end_station_latitude',
#        'end_station_longitude', 'trip_duration', 'subscriber', 'birth_year',
#        'age', 'gender'],
#       dtype='object')

# %%
# Create a subset excluding the "Date" and "No" columns

sub = Citi_df[['bike_id', 'weekday', 'weekday_index', 'start_hour',
       'start_time', 'start_station_id', 'start_station_name',
       'start_station_latitude', 'start_station_longitude', 'end_time',
       'end_station_id', 'end_station_name', 'end_station_latitude',
       'end_station_longitude', 'trip_duration', 'subscriber', 'birth_year','age',
       'gender']]

# %%
#Checking work
sub
# Out:
#        bike_id weekday  weekday_index  start_hour       start_time  \
# 0        16013     Mon              1          18   9/9/2013 18:18
# 1        15230     Thu              4          18  9/12/2013 18:38
# 2        17942     Wed              3          19  9/18/2013 19:44
# 3        19683     Sat              6          11  9/28/2013 11:54
# 4        18024     Sat              6          18   9/7/2013 18:08
# ...        ...     ...            ...         ...              ...
# 49995    17988     Sat              6          18  9/21/2013 18:39
# 49996    18458     Sat              6          17  9/14/2013 17:32
# 49997    15054     Sat              6          18   9/7/2013 18:08
# 49998    16763     Sat              6          13   9/7/2013 13:25
# 49999    16794     Mon              1          21  9/23/2013 21:54
#
#        start_station_id       start_station_name  start_station_latitude  \
# 0                   523          W 38 St & 8 Ave               40.754666
# ...

# %% [markdown]
# # Correlation Matrix

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(17,17))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(sub.corr(), annot = True, ax = ax) # The `annot` argument allows the plot to 
#place the correlation coefficients onto the heatmap.

# %% [markdown]
# This doesn't help a whole lot with any of the questions that I posed. A deeper dive into the variables will show a better representation of their interrelationship. Things I noticed from this are that birth year and age have a strong correlation (this won't do anything for me because it is obvious). Also the start station latitude and end station latitude have a strong correlation with each other, and the start station longitude and end station longitude have a more loose connection with each other. If you think about the shape of New York City Proper it is long north to south and a bit skinnier east to west.

# %% [markdown]
# # Scatterplot

# %%
# Scatterplots
# Create a scatterplot for the "birth year" and "gender" columns in seaborn

sns.lmplot(x = 'birth_year', y = 'age', data = sub)

# %% [markdown]
# As stated above, this does not help with the investigation. Also the latitude/longitude data will be investigated in a later task so I will not go at that variable here.

# %% [markdown]
# # Pair plot

# %%
# Keep only the variables you want to use in the pair plot

sub_2 = sub[['weekday_index', 'start_hour',
       'start_time', 'start_station_id','end_time',
       'end_station_id','trip_duration','age']]

# %%
# Create a pair plot 

g = sns.pairplot(sub_2)

# %% [markdown]
# Here is what jumps out at me
# 1) the age versus start hour as there seems to be some variance showing up there.
# 2) Start hour and trip duration has some holes to look in to.
# 3) The Station ID and age relationship looks like it could show me something worthwhile.
# 4) Age versus trip duration also looks like it could show me something.
# 5) An age profiling in general would be a good idea as well.
# 6) Trip duration versus itself shows in general a good picture of the behavior of users.
# 7) Start hour versus itself shows that people tend to use the bikes more in the afternoon commute hour versus the morning.

# %% [markdown]
# # Categorical Plots:

# %% [markdown]
# ## Creating a categorical variable that splits the "start_hour" column into categories

# %%
sns.histplot(Citi_df['start_hour'], bins = 20, kde = True)
# Out:
# <AxesSubplot:xlabel='start_hour', ylabel='Count'>

# %% [markdown]
# This shows that the majority of rentals occurr within the 7am to 10pm hour, with peaks at the 7 am hour and the 3pm-6pm hour. I'd be interested to look at this to see how it changes for the day of the week.

# %% [markdown]
# ## Creating a categorical variable that splits the "trip_duration" column into categories

# %%
sns.histplot(Citi_df['trip_duration'], bins = 20, kde = True)
# Out:
# <AxesSubplot:xlabel='trip_duration', ylabel='Count'>

# %%
#Showing weekday where monday = 1 through sunday = 7
sns.histplot(Citi_df['weekday_index'], bins = 20, kde = True)
# Out:
# <AxesSubplot:xlabel='weekday_index', ylabel='Count'>

# %% [markdown]
# This shows a peak between 400-500 seconds (6.66 minutes to 8.33 minutes)  of rental with most rentals being under 1000 seconds (16.66 minutes). There is a pretty big skew in the data that shows much more activity in the shorter rental times however there is a peak at over 2500 seconds (~41 minutes) **maybe people rent the bikes for exercise**. I'd like to cross the trip duration with start hour of the day to see if there is any peak that should be looked into further.

# %% [markdown]
# ## Questions posed and answers so far
# 1) What is distribution of the bikes at specific locations for the morning and evening rush hour so that the supply meets the demand and people will not need to take other means of transportation? This could prove for higher rental rates.
#
# This will have to be looked into further. I know how to do it, it was just not within the scope of this task.
#
# 2) What is the general distance that each bike travels so that a flag could be placed on higher mileage bikes to get maintenance at certain intervals?
#
# This is a more complicated problem to dig at, however some simple trigonometry to give rough estimates of mileage between the start and end waypoints can get at this. I could at least give an estimate to see if any bikes are being used more than others. This could be kept track of with odometers on the bikes however this does not seem to be available information in this dataset.
#
# 3) What is the difference between genders rental habits? Do males or females tend to ride further?
#
# This will take more looking in to. It wont be hard, however it was again not within the scope of this
#
# 4) What days of the week have higher rentals for what times of the day?
#
# As shown above there isnt a lot of variance for the amount of rentals. The chart above shows that Saturday is the least busy day but not by much. Further investigation will need to happen to show if there are duration variations for each given day of the week.
#
# 5) Along with the time of day investigation, I could look in to the lowest usage times to recommend when to perform maintenance so that the most bikes will be available as possible for peak usage times.
#
# It looks like 10-12 PM would be the best time to perform maintenance on the bikes. Further investigation will see if there is a certain time of a certain day that this should happen.
#
# ## Things that will lead to Hypothesis/things I am thinking about most.
#
# I am going to say that question 1 will help the most from a business standpoint. I am going to guess that there are definitely going to be busier rental stations that will need more bikes every morning. I am most excited to dig in to this question and get to the bottom of it.
#
# The second question that will develop into a hypothesis is question number 2. I think that this could help the company save money on more costly repairs that could be avoided with routine maintenance. EX, how often should brake pads/tires be replaced?
